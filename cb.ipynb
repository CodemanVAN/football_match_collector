# %%
import pandas as pd
import os
os.chdir(r'C:\Users\18249\Desktop\vpn')
os.getcwd()
title=['Unnamed: 0', '时间', '主队', '客队', '赛果', '总进球', '欧主初赔', '欧初平赔', '欧客初赔',
       '欧主临赔', '欧平临赔', '欧客临赔', '初盘', '临盘', '主初赔', '客初赔', '主临赔', '客临盘赔', '球初盘',
       '球临盘', '大球初盘', '小球初盘', '大球临盘', '小球临盘']
all_data=pd.DataFrame(columns=title)

# %%
all_data=pd.DataFrame(columns=title)
files=os.listdir('./all')

mp1={'nan':None,'半球': 0.5, '平手': 0, '半/一': 0.75, '平/半': 0.25, '一球': 1, '一/球半': 1.25, '球半': 1.5, '两球': 2, '球半/两': 1.75, '两球/两球半':2.25, '两球半/三球':2.75,
    '三球/三球半':3.25,'两球半/三球':2.75,'两半': 2.5, '两半/三': 2.75, '三球': 3, '两/两半': 2.25, '三/三半': 3.25, '三半': 3.5, '三球半':3.5,'三球半/四球':3.75,'两球半':2.5,'四球/四球半':4.25,
    '四球半/五球':4.75,'四球半':4.5,'五球':5,'半球': 0.5, '平手': 0, '半/一': 0.75, '平/半': 0.25, '一球': 1, '一/球半': 1.25, '球半': 1.5, '两球': 2, '球半/两': 1.75,
    '两球/两球半':2.25, '两球半/三球':2.75,
    '三球/三球半':3.25,'两球半/三球':2.75,'两半': 2.5, '两半/三': 2.75, '三球': 3, '两/两半': 2.25, '三/三半': 3.25, '三半': 3.5, '三球半':3.5,'三球半/四球':3.75,
    '三半/四': 3.75, '四球': 4, '四/四半': 4.25, '四半': 4.5, '四半/五': 4.75, '五球': 5, '半球/一球': 0.75, '一球/球半': 1.25, '球半/两球': 1.75,  '平手/半球': 0.25,
    '五球半/六球':5.75,'五球半':5.5,'六球':6,'五球/五球半':5.25,
    '三半/四': 3.75, '四球': 4, '四/四半': 4.25, '四半': 4.5, '四半/五': 4.75, '五球': 5, '半球/一球': 0.75, '一球/球半': 1.25, '球半/两球': 1.75,  '平手/半球': 0.25}
mp2={'1/1.5':1.25,'nan':None,'2.5/3球':2.75, '2.5球':2.5, '3球':3, '3.5球':3.5, '3/3.5球':3.25, '2/2.5球':2.25,'2球':2, '1.5/2球':1.75, '1.5球':1.5,
        '3.5/4球':3.75, '4球':4,'3.5球':3.5,'4/4.5球':4.25,'4.5球':4.5,'4.5/5球':4.75,'5.0球':5,'4.75球':4.75,'2.5/3':2.75, '2.5':2.5, '3':3, '3.5':3.5, '3/3.5':3.25, '2/2.5':2.25,'2':2, '1.5/2':1.75, '1.5':1.5,
        '3.5/4':3.75, '4':4,'3.5':3.5,'4/4.5':4.25,'4.5':4.5,'4.5/5':4.75,'5.0':5,'4.75':4.75,'5.5':5.5,'5/5.5':5.25,'5.5/6':5.75,'6':6,'5':5,'nan':None,'2.5/3球':2.75, '2.5球':2.5, '3球':3, '3.5球':3.5, '3/3.5球':3.25, '2/2.5球':2.25,'2球':2, '1.5/2球':1.75, '1.5球':1.5,
        '3.5/4球':3.75, '4球':4,'3.5球':3.5,'4/4.5球':4.25,'4.5球':4.5,'4.5/5球':4.75,'5.0球':5,'4.75球':4.75,'2.5/3':2.75, '2.5':2.5, '3':3, '3.5':3.5, '3/3.5':3.25, '2/2.5':2.25,'2':2, '1.5/2':1.75, '1.5':1.5,
        '3.5/4':3.75, '4':4,'3.5':3.5,'4/4.5':4.25,'4.5':4.5,'4.5/5':4.75,'5.0':5,'4.75':4.75,'5.5':5.5,'5/5.5':5.25,'5.5/6':5.75,'6':6,'5':5,'6.5/7':6.75,'6.5':6.5,'6/6.5':6.25,'7.0':7}
while files:
    name=os.path.join('all',files.pop())
    if 'Cover' in name:continue
    f=pd.read_excel(name)
    print(f.columns,name)
    if 'time' in f.columns:
        n=f
        #n=pd.read_excel(os.path.join('new',nfiles.pop()))
        
        tt=['Unnamed: 0', 'id', '时间', '主队', '客队', '赛果', '总进球',
            'give_full', 'give_half', 'sc_full', 'sc_half', '欧主初赔',
            '欧初平赔', '欧客初赔', '欧主临赔', '欧平临赔',
            '欧客临赔', '初盘', '临盘', '主初赔',
            '客初赔', '主临赔', '客临盘赔', '球初盘',
            '球临盘', '大球初盘', '小球初盘', '大球临盘',
            '小球临盘']
        n.columns=tt
        n.reset_index()
        for i in range(n.shape[0]):
            if not '-' in str(n.iloc[i]['赛果']):continue
            tp=n.iloc[i]['赛果'].split('-')
            n['总进球'][i]=int(tp[0])+int(tp[1])
            if int(tp[0])-int(tp[1])>0:n['赛果'][i]=1
            elif int(tp[0])-int(tp[1])==0:n['赛果'][i]=0
            else:n['赛果'][i]=-1
        nt=n.columns
        for i in nt:
            if not i in title:
                del n[i]
        op_file =n
        n=n.dropna(axis = 0)
        n.reset_index()
        length=op_file.shape[0]
        ntitle=list(op_file.columns)


        for i in range(length):
            if str(op_file.iloc[i]['初盘'])!=str(float('nan')):
                if '受' in str(op_file.iloc[i]['初盘']):
                    op_file['初盘'][i] =-mp1[op_file['初盘'][i][1:]]
                elif op_file['初盘'][i] in list(mp1.keys()):
                    op_file['初盘'][i] =mp1[op_file['初盘'][i]]
                    
            if str(op_file.iloc[i]['初盘'])!=str(float('nan')):
                if '受' in str(op_file['临盘'][i]):
                    op_file['临盘'][i] =-mp1[op_file['临盘'][i][1:]]
                elif op_file['临盘'][i] in list(mp1.keys()) :
                    op_file['临盘'][i] =mp1[op_file['临盘'][i]]
                if  op_file['球临盘'][i] in list(mp2.keys()):
                    op_file['球临盘'][i] =mp2[op_file['球临盘'][i]]
                if  op_file['球初盘'][i] in list(mp2.keys()):
                    op_file['球初盘'][i] =mp2[op_file['球初盘'][i]]
        for j in ntitle[5:]:
            op_file[j] = op_file[j].astype("float")
        del op_file[ntitle[0]]
        n=n.dropna(axis = 0)
        n.reset_index()
        n.to_excel('Cover'+name[4:])


    else:
        p=f
        #p=pd.read_excel(os.path.join('old',ofiles.pop()))
        p=p.dropna(axis =0)
        pt=p.columns
        for i in pt:
            if not i in title:
                del p[i]
        op_file =p
        length=op_file.shape[0]
        ntitle=list(op_file.columns)

        for i in ntitle:
            for j in range(length):
                if '↓' in str(op_file[i][j]) or '↑' in str(op_file[i][j]):
                    op_file[i][j]=op_file[i][j].replace('↓','')
                    op_file[i][j]=op_file[i][j].replace('↑','')
        for i in range(length):
            op_file['临盘'][i]=str(op_file['临盘'][i]).replace('↓','')
            op_file['临盘'][i]=str(op_file['临盘'][i]).replace('↑','')
            if '受' in str(op_file.iloc[i]['初盘']):
                op_file['初盘'][i] =-mp1[op_file['初盘'][i][1:]]
            elif op_file['初盘'][i] in mp1.keys() :
                op_file['初盘'][i] =mp1[op_file['初盘'][i]]
            if '受' in str(op_file['临盘'][i]):
                op_file['临盘'][i] =-mp1[op_file['临盘'][i][1:]]
            elif op_file['临盘'][i] in list(mp1.keys()) :
                op_file['临盘'][i] =mp1[op_file['临盘'][i]]
            if  op_file['球临盘'][i] in list(mp2.keys()):
                op_file['球临盘'][i] =mp2[op_file['球临盘'][i]]
            if  op_file['球初盘'][i] in list(mp2.keys()):
                op_file['球初盘'][i] =mp2[op_file['球初盘'][i]]
        for j in ntitle[5:]:
            op_file[j] = op_file[j].astype("float")#
        del op_file[ntitle[0]]
        p.to_excel('Cover'+name[4:])
# Out:
# Index(['Unnamed: 0', 'id', 'time', 'host', 'guest', 'full_res', 'half_res',
#        'give_full', 'give_half', 'sc_full', 'sc_half', 'op_org_host',
#        'op_org_equal', 'op_org_guest', 'op_last_host', 'op_last_equal',
#        'op_last_guest', 'yp_org_give_full', 'yp_last_give_half', 'yp_org_host',
#        'yp_org_guest', 'yp_last_host', 'yp_last_guest', 'org_ball',
#        'last_ball', 'org_big_ball', 'org_small_ball', 'last_big_ball',
#        'last_small_ball'],
#       dtype='object') all\黑山甲2020-2021数据.xlsx
# Index(['Unnamed: 0', 'id', 'time', 'host', 'guest', 'full_res', 'half_res',
#        'give_full', 'give_half', 'sc_full', 'sc_half', 'op_org_host',
#        'op_org_equal', 'op_org_guest', 'op_last_host', 'op_last_equal',
#        'op_last_guest', 'yp_org_give_full', 'yp_last_give_half', 'yp_org_host',
#        'yp_org_guest', 'yp_last_host', 'yp_last_guest', 'org_ball',
#        'last_ball', 'org_big_ball', 'org_small_ball', 'last_big_ball',
# ...

# %%
        for i in ntitle:
            for j in range(length):
                if '↓' in str(op_file[i][j]) or '↑' in str(op_file[i][j]):
                    op_file[i][j]=op_file[i][j].replace('↓','')
                    op_file[i][j]=op_file[i][j].replace('↑','')

# %%
file=os.listdir()
for f in file:
    dt=pd.read_excel(f)
    dt.reset_index()
    for i in range(dt.shape[0]):

        if '受' in str(dt['临盘'][i]):
            dt['临盘'][i] =-mp1[dt['临盘'][i][1:]]
        elif dt['临盘'][i] in list(mp1.keys()) :
            dt['临盘'][i] =mp1[dt['临盘'][i]]
        if '受' in str(dt.iloc[i]['初盘']):
            dt['初盘'][i] =-mp1[dt['初盘'][i][1:]]
        elif dt['初盘'][i] in mp1.keys() :
            dt['初盘'][i] =mp1[dt['初盘'][i]]
        if  dt['球临盘'][i] in list(mp2.keys()):
            dt['球临盘'][i] =mp2[dt['球临盘'][i]]
        if  dt['球初盘'][i] in list(mp2.keys()):
            dt['球初盘'][i] =mp2[dt['球初盘'][i]]
    dt.to_excel(f)

# %%
c=['Unnamed: 0', 'Unnamed: 0.1', '时间', '主队', '客队', '赛果', '总进球', '欧主初赔',
       '欧初平赔', '欧客初赔', '欧主临赔', '欧平临赔', '欧客临赔', '初盘', '临盘', '主初赔', '客初赔', '主临赔',
       '客临盘赔', '球初盘', '球临盘', '大球初盘', '小球初盘', '大球临盘', '小球临盘']

# %%
dt['初盘']
# Out:
# 0           0
# 1      受平手/半球
# 2        0.75
# 3         0.5
# 4        0.25
#         ...
# 235     一球/球半
# 236    受平手/半球
# 237     平手/半球
# 238     平手/半球
# 239        半球
# Name: 初盘, Length: 240, dtype: object

# %%
dt
# Out:
#      Unnamed: 0  Unnamed: 0.1                时间      主队      客队  赛果  总进球  \
# 0             0             0  2016-03-04 19:35    广州富力  河北华夏幸福  -1    3
# 1             1             1  2016-03-05 15:30    河南建业    上海上港   1    1
# 2             2             2  2016-03-05 19:35  上海绿地申花    延边富德   0    2
# 3             3             3  2016-03-05 20:00    江苏苏宁  山东鲁能泰山   1    3
# 4             4             4  2016-03-06 15:30   石家庄永昌  辽宁沈阳宏运  -1    1
# ..          ...           ...               ...     ...     ...  ..  ...
# 235         235           235  2016-05-14 19:35    江苏苏宁   石家庄永昌   0    0
# 236         236           236  2016-05-14 19:35  北京中赫国安    上海上港   1    3
# 237         237           237  2016-05-15 15:30    延边富德    重庆斯威   0    2
# 238         238           238  2016-05-15 19:35    浙江绿城  辽宁沈阳宏运   0    0
# 239         239           239  2016-05-15 19:35  上海绿地申花    广州富力   1    6
#
#          欧主初赔      欧初平赔      欧客初赔  ...   主初赔   客初赔   主临赔  客临盘赔    球初盘    球临盘  \
# ...
